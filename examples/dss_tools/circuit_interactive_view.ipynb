# %% [markdown]
# # Circuit Interactive View
#
# This notebook demonstrates how to visualize the circuit of a distribution feeder using the `py_dss_tools` package. The example covers compiling a DSS model, solving a power flow simulation, and generating various interactive circuit plots with custom parameters.

# %% [markdown]
# ## Step 1: Import Libraries
#
# In this section, we import the necessary libraries.

# %%
# Import necessary libraries
import os
import pathlib
import py_dss_interface
from py_dss_tools import dss_tools

# %% [markdown]
# ## Step 2: Define Script Path and DSS File Path
#
# We define the path to the script and the DSS file used in the simulation.

# %%
# Define the script path and path to the DSS file
dss_file = r"C:\PauloRadatz\GitHub\py_dss_tools\examples\feeders\123Bus\IEEE123Master.dss"

# %% [markdown]
# ## Step 3: Create an Instance of DSS
#
# We create an instance of the DSS class using `py_dss_interface` to initialize the simulation environment.

# %%
# Create an instance of DSS
dss = py_dss_interface.DSS()

# %% [markdown]
# ## Step 4: Connect DSS Instance to `dss_tools`
#
# We connect the DSS instance to `dss_tools` to enable the use of helper methods for visualization and analysis.

# %%
# Connect the DSS instance to the dss_tools
dss_tools.update_dss(dss)

# %% [markdown]
# ## Step 5: Compile the DSS Model and Load Bus Coordinates
#
# We compile the DSS model from the specified file and load the bus coordinates for visualization.

# %%
# Compile the DSS model from the specified file
dss.text(f"compile [{dss_file}]")
# Load bus coordinates for visualization
dss.text(f"buscoords buscoords.dat")
# Solve the power flow for the system
dss.text(f"solve")
# Out:
# ''

# %% [markdown]
# ## Step 6: Plot Active Power in the Circuit
#
# We can plot the active power in the circuit using the default parameters and then customize the plot title and line width.

# %%
# Plot active power using default parameters
dss_tools.interactive_view.circuit_plot(parameter="active power")
# Out:
# <div>                            <div id="5624d0bc-579b-4c2c-a2c7-1d00fc06b856" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5624d0bc-579b-4c2c-a2c7-1d00fc06b856")) {                    Plotly.newPlot(                        "5624d0bc-579b-4c2c-a2c7-1d00fc06b856",                        [{"hoverinfo":"skip","line":{"color":"rgb(0, 0, 131)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",3615.240796296541],["line.l115","149","1",3615.240796296541]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 0, 131)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(131, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",20.003554832008614],["line.l1","1","2",20.003554832008614]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(131, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(145, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",102.85391886931707],["line.l2","1","3",102.85391886931707]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(145, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(0, 15, 141)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",3433.0688390974074],["line.l3","1","7",3433.0688390974074]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 15, 141)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(135, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",40.01608467901361],["line.l4","3","4",40.01608467901361]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u00 ...

# %%
# Customize plot: Active power with title and custom line widths
dss_tools.interactive_view.circuit_plot(parameter="active power", title="Active Power [KW]", width_2ph=2, width_1ph=1)
# Out:
# <div>                            <div id="8fcc49ef-9376-4dbf-b988-599a5baf115c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fcc49ef-9376-4dbf-b988-599a5baf115c")) {                    Plotly.newPlot(                        "8fcc49ef-9376-4dbf-b988-599a5baf115c",                        [{"hoverinfo":"skip","line":{"color":"rgb(0, 0, 131)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",3615.240796296541],["line.l115","149","1",3615.240796296541]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 0, 131)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(131, 0, 0)","dash":"solid","width":1},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",20.003554832008614],["line.l1","1","2",20.003554832008614]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(131, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(145, 0, 0)","dash":"solid","width":1},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",102.85391886931707],["line.l2","1","3",102.85391886931707]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(145, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(0, 15, 141)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",3433.0688390974074],["line.l3","1","7",3433.0688390974074]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 15, 141)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(135, 0, 0)","dash":"solid","width":1},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",40.01608467901361],["line.l4","3","4",40.01608467901361]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u00 ...

# %% [markdown]
# ## Step 7: Customize Line Styles and Mark Specific Buses
#
# We can change the line styles and also mark specific buses on the circuit plot.

# %%
# Customize plot: Active power with custom dash style for lines
dss_tools.interactive_view.circuit_plot(parameter="active power", title="Active Power [KW] with dash", dash_2ph="dot", dash_1ph="dash")
# Out:
# <div>                            <div id="9dfa9cd7-773d-4174-822d-d6e90339ac6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dfa9cd7-773d-4174-822d-d6e90339ac6e")) {                    Plotly.newPlot(                        "9dfa9cd7-773d-4174-822d-d6e90339ac6e",                        [{"hoverinfo":"skip","line":{"color":"rgb(0, 0, 131)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",3615.240796296541],["line.l115","149","1",3615.240796296541]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 0, 131)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(131, 0, 0)","dash":"dash","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",20.003554832008614],["line.l1","1","2",20.003554832008614]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(131, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(145, 0, 0)","dash":"dash","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",102.85391886931707],["line.l2","1","3",102.85391886931707]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(145, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(0, 15, 141)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",3433.0688390974074],["line.l3","1","7",3433.0688390974074]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 15, 141)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(135, 0, 0)","dash":"dash","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",40.01608467901361],["line.l4","3","4",40.01608467901361]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eB ...

# %%
# Mark a specific bus in the circuit plot
bus_list = [dss_tools.interactive_view.circuit_get_bus_marker(name="79", marker_name="My Bus", color="red", size=20)]
dss_tools.interactive_view.circuit_plot(parameter="active power", title="Active Power [KW] with Marked Bus", dash_2ph="dot", dash_1ph="dash", bus_markers=bus_list)
# Out:
# <div>                            <div id="c9c1dc19-cc0a-4513-8217-81bb1a4f3521" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9c1dc19-cc0a-4513-8217-81bb1a4f3521")) {                    Plotly.newPlot(                        "c9c1dc19-cc0a-4513-8217-81bb1a4f3521",                        [{"hoverinfo":"skip","line":{"color":"rgb(0, 0, 131)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",3615.240796296541],["line.l115","149","1",3615.240796296541]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 0, 131)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(131, 0, 0)","dash":"dash","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",20.003554832008614],["line.l1","1","2",20.003554832008614]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(131, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(145, 0, 0)","dash":"dash","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",102.85391886931707],["line.l2","1","3",102.85391886931707]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(145, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(0, 15, 141)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",3433.0688390974074],["line.l3","1","7",3433.0688390974074]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(0, 15, 141)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(135, 0, 0)","dash":"dash","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",40.01608467901361],["line.l4","3","4",40.01608467901361]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eB ...

# %% [markdown]
# ## Step 8: Customize Power Settings and Voltage Plot
#
# We can adjust the colorbar settings for the power plot and also visualize the circuit voltage profile.

# %%
# Adjust power settings and plot active power with modified settings
dss_tools.interactive_view.active_power_settings.colorbar_cmax = 5000
dss_tools.interactive_view.active_power_settings.colorbar_title = "P max = 5000 kW"
dss_tools.interactive_view.circuit_plot(parameter="active power", title="Active Power [KW] with changes in the power settings")
# Out:
# <div>                            <div id="24883cc9-7cc8-46fb-8d47-76364464d5b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24883cc9-7cc8-46fb-8d47-76364464d5b0")) {                    Plotly.newPlot(                        "24883cc9-7cc8-46fb-8d47-76364464d5b0",                        [{"hoverinfo":"skip","line":{"color":"rgb(2, 135, 203)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",3615.240796296541],["line.l115","149","1",3615.240796296541]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(2, 135, 203)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(130, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",20.003554832008614],["line.l1","1","2",20.003554832008614]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(130, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(141, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",102.85391886931707],["line.l2","1","3",102.85391886931707]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(141, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(3, 171, 218)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",3433.0688390974074],["line.l3","1","7",3433.0688390974074]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eTotal P: \u003c\u002fb\u003e%{customdata[3]:.2f} kW\u003cbr\u003e","marker":{"color":"rgb(3, 171, 218)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(133, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",40.01608467901361],["line.l4","3","4",40.01608467901361]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003 ...

# %%
# Plot the voltage in the circuit
dss_tools.interactive_view.circuit_plot(parameter="voltage", title="Voltage [pu]")
# Out:
# <div>                            <div id="60cf6de2-2c16-4e44-bb58-b53f42d2321d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60cf6de2-2c16-4e44-bb58-b53f42d2321d")) {                    Plotly.newPlot(                        "60cf6de2-2c16-4e44-bb58-b53f42d2321d",                        [{"hoverinfo":"skip","line":{"color":"rgb(0, 34, 153)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",1.0374891391881864],["line.l115","149","1",1.0374891391881864]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eMean Bus2 Voltage: \u003c\u002fb\u003e%{customdata[3]:.4f} pu\u003cbr\u003e","marker":{"color":"rgb(0, 34, 153)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(0, 46, 161)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",1.0351181468017672],["line.l1","1","2",1.0351181468017672]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eMean Bus2 Voltage: \u003c\u002fb\u003e%{customdata[3]:.4f} pu\u003cbr\u003e","marker":{"color":"rgb(0, 46, 161)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(2, 123, 198)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",1.0285903099635887],["line.l2","1","3",1.0285903099635887]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eMean Bus2 Voltage: \u003c\u002fb\u003e%{customdata[3]:.4f} pu\u003cbr\u003e","marker":{"color":"rgb(2, 123, 198)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(1, 108, 191)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",1.0295560223590379],["line.l3","1","7",1.0295560223590379]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eMean Bus2 Voltage: \u003c\u002fb\u003e%{customdata[3]:.4f} pu\u003cbr\u003e","marker":{"color":"rgb(1, 108, 191)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(2, 151, 209)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",1.0269452222162834],["line.l4","3","4",1.0269452222162834]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003 ...

# %% [markdown]
# ## Step 9: Plot Phases in the Circuit
#
# We can visualize the phases in the circuit using a categorical plot, assigning specific colors to 3-phase, 2-phase, and 1-phase lines.

# %%
dss_tools.interactive_view.circuit_plot(parameter="phases", title="Phases")
# Out:
# <div>                            <div id="79fd34d9-6894-47b6-b9f6-3aadfe9114b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79fd34d9-6894-47b6-b9f6-3aadfe9114b0")) {                    Plotly.newPlot(                        "79fd34d9-6894-47b6-b9f6-3aadfe9114b0",                        [{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"3-phases","showlegend":true,"x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1","3"],["line.l115","149","1","3"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":true,"x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2","1"],["line.l1","1","2","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3","1"],["line.l2","1","3","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"3-phases","showlegend":false,"x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7","3"],["line.l3","1","7","3"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003ePhases: \u003c\u002fb\u003e%{customdata[3]}\u003cbr\u003e","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Line Phases"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4","1"],["line.l4","3","4","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u00 ...

# %% [markdown]
# ## Step 10: User-Defined Numerical and Categorical Plots
#
# We can create user-defined numerical and categorical circuit plots by specifying custom results and settings.

# %%
# User-defined numerical plot: Active power in MW
dss_tools.interactive_view.user_numerical_defined_settings.results = dss_tools.results.powers_elements[0].iloc[:, :3].sum(axis=1) / 1000
dss_tools.interactive_view.user_numerical_defined_settings.unit = "MW"
dss_tools.interactive_view.circuit_plot(parameter="user numerical defined", title="Active Power [MW]")
# Out:
# <div>                            <div id="ad3a0099-cf09-4ae5-a2e9-c6d3d6262273" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad3a0099-cf09-4ae5-a2e9-c6d3d6262273")) {                    Plotly.newPlot(                        "ad3a0099-cf09-4ae5-a2e9-c6d3d6262273",                        [{"hoverinfo":"skip","line":{"color":"rgb(0, 0, 131)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l115","x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1",3.6152407962965407],["line.l115","149","1",3.6152407962965407]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Numerical Defined:\u003c\u002fb\u003e %{customdata[3]:.2f} MW\u003cbr\u003e","marker":{"color":"rgb(0, 0, 131)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(131, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l1","x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2",0.020003554832008615],["line.l1","1","2",0.020003554832008615]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Numerical Defined:\u003c\u002fb\u003e %{customdata[3]:.2f} MW\u003cbr\u003e","marker":{"color":"rgb(131, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(145, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l2","x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3",0.10285391886931707],["line.l2","1","3",0.10285391886931707]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Numerical Defined:\u003c\u002fb\u003e %{customdata[3]:.2f} MW\u003cbr\u003e","marker":{"color":"rgb(145, 0, 0)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(0, 15, 141)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l3","x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7",3.4330688390974076],["line.l3","1","7",3.4330688390974076]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Numerical Defined:\u003c\u002fb\u003e %{customdata[3]:.2f} MW\u003cbr\u003e","marker":{"color":"rgb(0, 15, 141)","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","line":{"color":"rgb(135, 0, 0)","dash":"solid","width":3},"mode":"lines+markers","name":"","showlegend":false,"text":"line.l4","x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4",0.04001608467901361],["line.l4","3","4",0.04001608467901361]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u ...

# %%
# User-defined categorical plot: Phases in the circuit
line_df = dss_tools.model.lines_df
line_df['name'] = 'line.' + line_df['name']
num_phases = line_df.set_index("name")["phases"]

dss_tools.interactive_view.user_categorical_defined_settings.results = num_phases
dss_tools.interactive_view.user_categorical_defined_settings.color_map = {
    '3': ["3-phases", "blue"],
    '2': ["2-phases", "red"],
    '1': ["1-phase", "green"]
}
dss_tools.interactive_view.circuit_plot(parameter="user categorical defined", title="My Phases")
# Out:
# <div>                            <div id="100bf64a-6dce-4069-98d1-763a6443000d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("100bf64a-6dce-4069-98d1-763a6443000d")) {                    Plotly.newPlot(                        "100bf64a-6dce-4069-98d1-763a6443000d",                        [{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Legend Title"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"3-phases","showlegend":true,"x":[300.0,700.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l115","149","1","3"],["line.l115","149","1","3"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Categorical Defined:\u003c\u002fb\u003e %{customdata[3]}","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[500.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Legend Title"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":true,"x":[700.0,700.0],"y":[1500.0,1675.0],"type":"scatter"},{"customdata":[["line.l1","1","2","1"],["line.l1","1","2","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Categorical Defined:\u003c\u002fb\u003e %{customdata[3]}","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1587.5],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Legend Title"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[700.0,700.0],"y":[1500.0,1250.0],"type":"scatter"},{"customdata":[["line.l2","1","3","1"],["line.l2","1","3","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Categorical Defined:\u003c\u002fb\u003e %{customdata[3]}","legendgroup":"group","marker":{"color":"green","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[700.0],"y":[1375.0],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Legend Title"},"line":{"color":"blue","dash":"solid","width":3},"mode":"lines+markers","name":"3-phases","showlegend":false,"x":[700.0,1000.0],"y":[1500.0,1500.0],"type":"scatter"},{"customdata":[["line.l3","1","7","3"],["line.l3","1","7","3"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e\u003cb\u003eBus1: \u003c\u002fb\u003e%{customdata[1]} | \u003cb\u003eBus2: \u003c\u002fb\u003e%{customdata[2]}\u003cbr\u003e\u003cb\u003eUser Categorical Defined:\u003c\u002fb\u003e %{customdata[3]}","legendgroup":"group","marker":{"color":"blue","opacity":0,"size":0.1},"mode":"markers","name":"","showlegend":false,"x":[850.0],"y":[1500.0],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"group","legendgrouptitle":{"text":"Legend Title"},"line":{"color":"green","dash":"solid","width":3},"mode":"lines+markers","name":"1-phase","showlegend":false,"x":[700.0,700.0],"y":[1250.0,1050.0],"type":"scatter"},{"customdata":[["line.l4","3","4","1"],["line.l4","3","4","1"]],"hoverinfo":"text","hovertemplate":"\u003cb\u003e%{cus ...

# %% [markdown]
# ## Conclusion
#
# In this notebook, we demonstrated how to visualize the circuit of a distribution feeder using the `py_dss_tools` package. We covered compiling the DSS model, solving a power flow simulation, and generating various interactive circuit plots. The flexibility provided by `dss_tools` allows for detailed and customized visualizations of distribution systems, making it easy to analyze different electrical parameters such as active power and voltage, as well as user-defined numerical and categorical data.
