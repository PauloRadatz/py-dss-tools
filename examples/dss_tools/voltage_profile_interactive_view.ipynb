# %% [markdown]
# # Voltage Profile Interactive View Example
#
# This notebook demonstrates how to use the `py_dss_tools` package to visualize the interactive version of the voltage profile of a distribution feeder. The example covers compiling a DSS model, solving a snapshot simulation, and generating various voltage profile plots.

# %%
import py_dss_interface
from py_dss_tools import dss_tools

# %% [markdown]
# Define the path to the DSS file

# %%
dss_file = r"C:\PauloRadatz\GitHub\py_dss_tools\examples\feeders\123Bus\IEEE123Master.dss"

# %% [markdown]
# Create an instance of DSS

# %%
dss = py_dss_interface.DSS()

# %% [markdown]
# Connect DSS instance to the dss_tools

# %%
dss_tools.update_dss(dss)

# %% [markdown]
# Compile the DSS model from the specified file, load bus coordinates for visualization

# %%
dss.text(f"compile [{dss_file}]")
dss.text(f"buscoords buscoords.dat")
# Out:
# ''

# %% [markdown]
# Add EnergyMeter and Solve Snapshot. An energymeter is added at the feeder head, and a snapshot simulation is solved to prepare for plotting the voltage profile.

# %%
dss_tools.model.add_line_in_vsource(add_meter=True)
dss_tools.simulation.solve_snapshot()

# %% [markdown]
# ### Plot Voltage Profile with Default Parameters
#
# The voltage profile of the feeder is plotted using the default parameters.

# %%
dss_tools.interactive_view.voltage_profile()
# Out:
# <div>                            <div id="51ddd136-609e-4145-896e-09528dedffd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51ddd136-609e-4145-896e-09528dedffd9")) {                    Plotly.newPlot(                        "51ddd136-609e-4145-896e-09528dedffd9",                        [{"customdata":[["149"],["1"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":true,"x":[0.002,0.402],"y":[1.0371183718391557,1.024589316768391],"type":"scatter"},{"customdata":[["1"],["2"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.577],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["3"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.652],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["7"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.702],"y":[1.024589316768391,1.0152579759253157],"type":"scatter"},{"customdata":[["3"],["4"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.8520000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["3"],["5"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.9770000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["5"],["6"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9770000000000001,1.227],"y":[null,null],"type":"scatter"},{"customdata":[["7"],["8"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.702,0.9019999999999999],"y":[1.0152579759253157,1.0092047454113677],"type":"scatter"},{"customdata":[["8"],["12"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9019999999999999,1.127],"y":[1.0092047454113677,null],"type":"scatter"},{"customdata":[["8"],["9"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDista ...

# %% [markdown]
# ### Plot Voltage Profile with Custom Title
#
# We can customize the voltage profile plot by providing argument values to the `voltage_profile` method.

# %%
dss_tools.interactive_view.voltage_profile(title=f"Voltage profile for feeder {dss.circuit.name}")
# Out:
# <div>                            <div id="a1035135-ef54-4db2-9118-fbacc39ab9e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1035135-ef54-4db2-9118-fbacc39ab9e0")) {                    Plotly.newPlot(                        "a1035135-ef54-4db2-9118-fbacc39ab9e0",                        [{"customdata":[["149"],["1"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":true,"x":[0.002,0.402],"y":[1.0371183718391557,1.024589316768391],"type":"scatter"},{"customdata":[["1"],["2"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.577],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["3"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.652],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["7"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.702],"y":[1.024589316768391,1.0152579759253157],"type":"scatter"},{"customdata":[["3"],["4"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.8520000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["3"],["5"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.9770000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["5"],["6"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9770000000000001,1.227],"y":[null,null],"type":"scatter"},{"customdata":[["7"],["8"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.702,0.9019999999999999],"y":[1.0152579759253157,1.0092047454113677],"type":"scatter"},{"customdata":[["8"],["12"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9019999999999999,1.127],"y":[1.0092047454113677,null],"type":"scatter"},{"customdata":[["8"],["9"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDista ...

# %% [markdown]
# ### Mark Specific Buses in the Voltage Profile
#
# We can annotate specific buses in the voltage profile by marking them with custom labels. We should pass a list of `dss_tools.static_view.voltage_profile_get_bus_mark` objects to the `buses_marker` argument of the `voltage_profile` method.

# %%
buses_marker = [dss_tools.interactive_view.voltage_profile_get_bus_mark("149", annotate=True, annotation_label="Bus")]
dss_tools.interactive_view.voltage_profile(buses_marker=buses_marker)
# Out:
# <div>                            <div id="6fae2164-8d75-4e60-8d59-2216096e1286" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fae2164-8d75-4e60-8d59-2216096e1286")) {                    Plotly.newPlot(                        "6fae2164-8d75-4e60-8d59-2216096e1286",                        [{"customdata":[["149"],["1"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":true,"x":[0.002,0.402],"y":[1.0371183718391557,1.024589316768391],"type":"scatter"},{"customdata":[["149"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers","name":"Bus","showlegend":false,"x":[0.002],"y":[1.0371183718391557],"type":"scatter"},{"customdata":[["1"],["2"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.577],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["3"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.652],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["7"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.702],"y":[1.024589316768391,1.0152579759253157],"type":"scatter"},{"customdata":[["3"],["4"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.8520000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["3"],["5"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.9770000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["5"],["6"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9770000000000001,1.227],"y":[null,null],"type":"scatter"},{"customdata":[["7"],["8"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.702,0.9019999999999999],"y":[1.0152579759253157,1.0092047454113677],"type":"scatter"},{"customdata":[["8"],["12"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f ...

# %% [markdown]
# ### Customize Plotly Attributes for Voltage Profile Plot
#
# We can modify Plotly attributes, such as grid visibility, for the voltage profile plot.

# %%
dss_tools.interactive_view.voltage_profile_plot_style.show_grid = False
dss_tools.interactive_view.voltage_profile()
# Out:
# <div>                            <div id="d8f444ad-257d-4aa8-bff3-2b19b9b6bab9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8f444ad-257d-4aa8-bff3-2b19b9b6bab9")) {                    Plotly.newPlot(                        "d8f444ad-257d-4aa8-bff3-2b19b9b6bab9",                        [{"customdata":[["149"],["1"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":true,"x":[0.002,0.402],"y":[1.0371183718391557,1.024589316768391],"type":"scatter"},{"customdata":[["1"],["2"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.577],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["3"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.652],"y":[1.024589316768391,null],"type":"scatter"},{"customdata":[["1"],["7"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.402,0.702],"y":[1.024589316768391,1.0152579759253157],"type":"scatter"},{"customdata":[["3"],["4"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.8520000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["3"],["5"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.652,0.9770000000000001],"y":[null,null],"type":"scatter"},{"customdata":[["5"],["6"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9770000000000001,1.227],"y":[null,null],"type":"scatter"},{"customdata":[["7"],["8"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.702,0.9019999999999999],"y":[1.0152579759253157,1.0092047454113677],"type":"scatter"},{"customdata":[["8"],["12"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDistance: %{x}\u003cbr\u003eVoltage: %{y:.3f} pu\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Node 1","line":{"color":"black"},"marker":{"color":"black"},"mode":"lines+markers","name":"Node 1","showlegend":false,"x":[0.9019999999999999,1.127],"y":[1.0092047454113677,null],"type":"scatter"},{"customdata":[["8"],["9"]],"hovertemplate":"Bus: %{customdata[0]}\u003cbr\u003eDista ...

# %% [markdown]
# ### Conclusion
#
# In this notebook, we demonstrated how to visualize the interactive option of the voltage profile of a distribution feeder using the `py_dss_tools` package. We covered the process of compiling a DSS model, adding an energymeter, solving a snapshot simulation, and generating various voltage profile plots. The `py_dss_tools` package provides flexibility in customizing the plots, allowing users to adjust titles, annotate specific buses, and modify Matplotlib attributes to suit their needs.
